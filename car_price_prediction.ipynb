# %% [markdown]
#  <font color = Blue size = 5> Car Price Prediction using Machine Learning. </font>

# %% [markdown]
# Մեքենայի գինը կախված է բազմաթիվ գործոններից, ինչպիսիք են մեքենայի ապրանքանիշը, մեքենայի առանձնահատկությունները՝ ձիաուժը, վազքը և շատ ավելին:Մեքենաների գների կանխատեսման դեպքում ընկերությունները կարող են օգտագործել այս տեխնոլոգիան՝ որոշելու իրենց արտադրած նոր մեքենաների գները, ինչը կօգնի նրանց սահմանել իրենց մեքենաների ճշգրիտ գները՝ ելնելով մեքենաների շուկայական արժեքից: Արդյունքում, մեքենաների օպտիմալ գները կարող են սահմանվել, ինչը համապատասխանաբար ավելի լավ աճի և արդյունքների կբերի ավտոմեքենա արտադրողների համար:
#
# 💡 Մեքենայի գների կանխատեսումը մեքենայական ուսուցման հիմնական հետազոտության ոլորտներից մեկն է:
# Մեքենայի գների կանխատեսման համար կարող ենք օգտագործել մեքենայական ուսուցման տարբեր մոդելներ, ինչպիսիք են գծային ռեգրեսիան( Linear Regression), պատահական անտառային ռեգրեսիան(Random Forest Regression), գրադիենտի բարձրացման ռեգրեսիան( Gradient Boosting Regression) և նեյրոնային ցանցերը(Neural Networks):
#
# Գծային ռեգրեսիան պարզ և լայնորեն օգտագործվող մոդել է, որը կարող է լավ արդյունքներ տալ, եթե տվյալները գծորեն բաժանելի են: Պատահական անտառային ռեգրեսիան ավելի բարդ մոդել է, որը կարող է մշակել ոչ գծային տվյալներ և կարող է ավելի լավ արդյունքներ տալ, քան գծային ռեգրեսիան: Gradient Boosting Regression-ը ևս մեկ հզոր մոդել է, որը կարող է մշակել ոչ գծային տվյալներ և կարող է նույնիսկ ավելի լավ արդյունքներ տալ, քան Random Forest Regression-ը: Նյեյրոնային ցանցերը ամենաբարդ մոդելներն են և կարող են տալ լավագույն արդյունքները, սակայն դրանք պահանջում են շատ տվյալներ և հաշվողական հզորություն:
#
# 💡 Այս առաջադրանքում մենք պետք է վերապատրաստենք մեքենայական ուսուցման մոդել, որը կկանխատեսի մեքենաների գինը՝ օգտագործելով մեքենայի տարբեր հատկանիշները։

# %% [markdown]
#  <font color = red size = 5> Authors: Monica Avagyan</font>
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Business Goal
#
#
# Մեզանից պահանջվում է մոդելավորել մեքենաների գինը առկա անկախ փոփոխականներով: Այն կօգտագործվի ղեկավարության կողմից՝ հասկանալու համար, թե կոնկրետ ինչպես են գները տարբերվում անկախ փոփոխականներից: Նրանք կարող են համապատասխանաբար շահարկել մեքենաների դիզայնը, բիզնես ռազմավարությունը և այլ հատկանիշներ՝ որոշակի գների մակարդակին համապատասխանելու համար:Մոդելը լավ միջոց կլինի ղեկավարության համար՝ հասկանալու նոր շուկայի գնագոյացման դինամիկան:

# %% [markdown]
# ## Importing libraries

# %%
import warnings
warnings.filterwarnings('ignore')   #Զգուշացումները(warnings) գրադարան է, որն օգտագործվում է  կոդի նախազգուշացումները ճնշելու(ignore) համար:

#importing the libraries
import numpy as np                  #NumPy-ն օգտագործվում է զանգվածների և մատրիցների համար մաթեմատիկական գործողություններ կատարելու համար:
import pandas as pd                  #Pandas-ը գրադարան է, որն օգտագործվում է տվյալների վերլուծության համար:
import matplotlib.pyplot as plt        #Matplotlib-ը գրադարան է Python-ում  անիմացիոն և ինտերակտիվ վիզուալիզացիաներ ստեղծելու համար:
import seaborn as sns                 #Seaborn-ն ապահովում է բարձր մակարդակի ինտերֆեյս, որն օգտագործվում է տեղեկատվական վիճակագրական plot-ներ նկարելու համար:

# %% [markdown]
# ### Step 1: Reading and Understanding the Data
#
#
# 1. Importing data using the pandas library
# 2. Understanding the structure of the data

# %%
cars = pd.read_csv('CarPrice_Assignment.csv')   # Load the data
cars.head()          #տվյալերի բազայի առաջին 5 տողերը
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
cars.shape      # Տվյալների բազայի  չափերի ստուգում
# Out:
# (205, 26)

# %%
cars.describe()   #Նկարագրական վիճակագրության վերլուծություն
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
cars.info()          #Տվյալների բազայի հիմնական տեղեկատվության ստուգում
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %% [markdown]
# Վերևից մենք կարող ենք տեսնել, որ 10 դասակարգային(object) և 8 թվային(float & int) հատկանիշներ:
# Բոլոր հատկանիշներն ունեն տվյալների ճիշտ տեսակներ: Այսպիսով, մենք չպետք է որևէ փոփոխություն անենք:

# %% [markdown]
# ### Step 2 : Data Cleaning and Preparation

# %% [markdown]
# <font size = 3 color = green>CarName</font>  Feature-ում մենք կարող ենք նկատել, որ արժեքները պահում են ինչպես մեքենայի ընկերության անվանումը, այնպես էլ մեքենայի անվանումը:
# Այսպիսով, մենք պետք է մաքրենք այդ հատկությունը:
# Մենք կարող ենք առանձնացնել մեքենաների ընկերությունների անվանումները <font size = 3 color = green>CarName</font> Feature-ից:

# %%
#Splitting company name from CarName column
CompanyName = cars['CarName'].apply(lambda x : x.split(' ')[0])
cars.insert(3,"CompanyName",CompanyName)
cars.drop(['CarName'],axis=1,inplace=True)
cars.head()
# Out:
#    car_ID  symboling  CompanyName fueltype aspiration doornumber      carbody  \
# 0       1          3  alfa-romero      gas        std        two  convertible
# 1       2          3  alfa-romero      gas        std        two  convertible
# 2       3          1  alfa-romero      gas        std        two    hatchback
# 3       4          2         audi      gas        std       four        sedan
# 4       5          2         audi      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0        rwd          front       88.6  ...         130        mpfi
# 1        rwd          front       88.6  ...         130        mpfi
# 2        rwd          front       94.5  ...         152        mpfi
# 3        fwd          front       99.8  ...         109        mpfi
# 4        4wd          front       99.4  ...         136        mpfi
#
#    boreratio  stroke compressionratio horsepower  peakrpm citympg  highwaympg  \
# ...

# %%
cars.CompanyName.unique()    #Checking the Unique Car Company Names
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %% [markdown]
# ##### Fixing invalid values
# -  Ընկերության անունը սյունակում ուղղագրական սխալ կա:
#
#     - `maxda` = `mazda`
#     - `Nissan` = `nissan`
#     - `porsche` = `porcshce`
#     - `toyota` = `toyouta`
#     - `vokswagen` = `volkswagen` =  `vw`

# %%
cars.CompanyName = cars.CompanyName.str.lower()

def replace_name(a,b):
    cars.CompanyName.replace(a,b,inplace=True)

replace_name('maxda','mazda')
replace_name('porcshce','porsche')
replace_name('toyouta','toyota')
replace_name('vokswagen','volkswagen')
replace_name('vw','volkswagen')

cars.CompanyName.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi',
#        'nissan', 'peugeot', 'plymouth', 'porsche', 'renault', 'saab',
#        'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
#Checking for duplicates
cars.loc[cars.duplicated()]
# Out:
# Empty DataFrame
# Columns: [car_ID, symboling, CompanyName, fueltype, aspiration, doornumber, carbody, drivewheel, enginelocation, wheelbase, carlength, carwidth, carheight, curbweight, enginetype, cylindernumber, enginesize, fuelsystem, boreratio, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
cars.columns
# Out:
# Index(['car_ID', 'symboling', 'CompanyName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %% [markdown]
# ### Step 3: Visualizing the data

# %% [markdown]
# Visualizing Total No. of cars sold by different company

# %%
plt.figure(figsize=(14,6))
counts = cars["CompanyName"].value_counts()
sns.barplot(x=counts.index, y=counts.values)
plt.xlabel("Car Company")
plt.ylabel("Total No. of cars sold")
plt.title("Total Cars produced by Companies", pad=20, fontweight="black", fontsize=30)
plt.xticks(rotation=90)
plt.show()

# %%
cars[cars["CompanyName"]=="honda"]
# Out:
#     car_ID  symboling CompanyName fueltype aspiration doornumber    carbody  \
# 30      31          2       honda      gas        std        two  hatchback
# 31      32          2       honda      gas        std        two  hatchback
# 32      33          1       honda      gas        std        two  hatchback
# 33      34          1       honda      gas        std        two  hatchback
# 34      35          1       honda      gas        std        two  hatchback
# 35      36          0       honda      gas        std       four      sedan
# 36      37          0       honda      gas        std       four      wagon
# 37      38          0       honda      gas        std        two  hatchback
# 38      39          0       honda      gas        std        two  hatchback
# 39      40          0       honda      gas        std       four      sedan
# 40      41          0       honda      gas        std       four      sedan
# ...

# %%
cars[cars["CompanyName"]=="jaguar"]
# Out:
#     car_ID  symboling CompanyName fueltype aspiration doornumber carbody  \
# 47      48          0      jaguar      gas        std       four   sedan
# 48      49          0      jaguar      gas        std       four   sedan
# 49      50          0      jaguar      gas        std        two   sedan
#
#    drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 47        rwd          front      113.0  ...         258        mpfi
# 48        rwd          front      113.0  ...         258        mpfi
# 49        rwd          front      102.0  ...         326        mpfi
#
#     boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 47       3.63    4.17              8.1        176     4750      15
# 48       3.63    4.17              8.1        176     4750      15
# 49       3.54    2.76             11.5        262     5000      13
#
#     highwaympg    price
# 47          19  32250.0
# 48          19  35550.0
# 49          17  36000.0
#
# ...

# %% [markdown]
# Ամենաշատ մեքենաները վաճառել է Toyota ընկերությունը։ Այսպիսով, կարելի է ասել, որ Toyota-ն հաճախորդների ամենասիրված ընկերությունն է: Chevrolet-ը, Mercury-ն կամ Renault-ն ունեն շատ քիչ տվյալներ: Այսպիսով, մենք չենք կարող որևէ եզրակացություն անել ամենաքիչ վաճառվող ավտոմեքենաների ընկերությունների մասին:

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('Car Price Distribution Plot')
sns.distplot(cars.price)

plt.subplot(1,2,2)
plt.title('Car Price Spread')
sns.boxplot(y=cars.price)

plt.show()

# %%
print(cars.price.describe(percentiles = [0.25,0.50,0.75,0.85,0.90,1]))
# Out:
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 25%       7788.000000
# 50%      10295.000000
# 75%      16503.000000
# 85%      18500.000000
# 90%      22563.000000
# 100%     45400.000000
# max      45400.000000
# Name: price, dtype: float64

# %% [markdown]
# #### Եզրակացություն :
#
# 1. Թվում է,որ տվյալները ճիշտ են շեղված, ինչը նշանակում է, որ տվյալների հավաքածուի ամենաշատ գները ցածր են (15000-ից ցածր):
#
# 2. Գների բաշխման միջին և միջինի միջև զգալի տարբերություն կա:
#
# 3. Տվյալների կետերը շատ հեռու են միջինից, ինչը ցույց է տալիս մեքենաների գների բարձր տարբերություն: (գների 85%-ը 18500-ից ցածր է, մինչդեռ մնացած 15%-ը 18500-ից 45400-ի միջև է):

# %% [markdown]
# ### Step 3.1 : Visualising Categorical Data
#
#     - CompanyName
#     - Symboling
#     - fueltype
#     - enginetype
#     - carbody
#     - doornumber
#     - enginelocation
#     - fuelsystem
#     - cylindernumber
#     - aspiration
#     - drivewheel

# %%
plt.figure(figsize=(25, 6))
plt.subplot(1, 3, 1)
plt1 = cars.CompanyName.value_counts().plot(kind="bar")
plt.title("Companies Histogram")
plt1.set(xlabel="Car company", ylabel="Frequency of company")

plt.subplot(1,3,2)
plt1 = cars.fueltype.value_counts().plot(kind="bar")
plt.title("Fuel Type Histogram")
plt1.set(xlabel="Fuel Type", ylabel="Frequency of fuel type")

plt.subplot(1,3,3)
plt1 = cars.carbody.value_counts().plot(kind="bar")
plt.title("Car Type Histogram")
plt1.set(xlabel="Car Type", ylabel="Frequency of Car type")
plt.show()

# %% [markdown]
# #### Եզրակացություն :
#
# 1. «Toyota»-ն, կարծես, սիրված ավտոմոբիլային ընկերություն է:
# 2. «Գազով» ավտոմեքենաների թիվն ավելի շատ է, քան «դիզելային»։
# 3. «Սեդան»-ը նախընտրելի ավտոմեքենայի լավագույն տեսակն է:

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('Symboling Histogram')
sns.countplot(cars.symboling, palette=("cubehelix"))

plt.subplot(1,2,2)
plt.title('Symboling vs Price')
sns.boxplot(x=cars.symboling, y=cars.price, palette=("cubehelix"))

plt.show()

# %% [markdown]
# #### Եզրակացություն :
#
# 1. Թվում է, թե «0» և «1» արժեքներով symbol-ները ամենամեծն են  (այսինքն՝ դրանք ամենաշատն են վաճառվում):
# 2. Թվում է, թե «-1» symbol-ներով մեքենաները թանկ են (քանի որ դա նույնպես իմաստալից է, ապահովագրական ռիսկի վարկանիշը -1 բավականին լավ է): Բայց թվում է, որ «3» արժեքով symbol-ն ունի «-2» արժեքի նման գնային միջակայք: «1»-ը  գնի անկում է նկատվում:

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('Engine Type Histogram')
sns.countplot(cars.enginetype, palette=("Blues_d"))

plt.subplot(1,2,2)
plt.title('Engine Type vs Price')
sns.boxplot(x=cars.enginetype, y=cars.price, palette=("PuBuGn"))

plt.show()

df = pd.DataFrame(cars.groupby(['enginetype'])['price'].mean().sort_values(ascending = False))
df.plot.bar(figsize=(8,6))
plt.title('Engine Type vs Average Price')
plt.show()

# %% [markdown]
# #### Եզրակացություն :
#
# 1. «ohc» Շարժիչի տեսակը, թվում է, ամենանախընտրելի տեսակն է:
# 2. «ohcv»-ն ունի ամենաբարձր գների միջակայքը (Մինչ «dohcv»-ն ունի միայն մեկ տող), «ohc»-ն և «ohcf»-ն ունեն ցածր գնային միջակայք:

# %%
plt.figure(figsize=(25, 6))

df = pd.DataFrame(cars.groupby(['CompanyName'])['price'].mean().sort_values(ascending = False))
df.plot.bar()
plt.title('Company Name vs Average Price')
plt.show()

df = pd.DataFrame(cars.groupby(['fueltype'])['price'].mean().sort_values(ascending = False))
df.plot.bar()
plt.title('Fuel Type vs Average Price')
plt.show()

df = pd.DataFrame(cars.groupby(['carbody'])['price'].mean().sort_values(ascending = False))
df.plot.bar()
plt.title('Car Type vs Average Price')
plt.show()

# %% [markdown]
# #### Եզրակացություն :
#
# 1. «Jaguar»-ը և «Buick»-ը  ամենաբարձր միջին գինն ունեն:
# 2. «Դիզելն» ավելի բարձր միջին գին ունի, քան գազը։
# 3. «Hardtop»-ը և «Convertible»-ն ունեն ավելի բարձր միջին գին:

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.title('Door Number Histogram')
sns.countplot(cars.doornumber, palette=("plasma"))

plt.subplot(1,2,2)
plt.title('Door Number vs Price')
sns.boxplot(x=cars.doornumber, y=cars.price, palette=("plasma"))

plt.show()

plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.title('Aspiration Histogram')
sns.countplot(cars.aspiration, palette=("plasma"))

plt.subplot(1,2,2)
plt.title('Aspiration vs Price')
sns.boxplot(x=cars.aspiration, y=cars.price, palette=("plasma"))

plt.show()

# %% [markdown]
# #### Եզրակացություն :
#
# 1. «doornumber» փոփոխականը շատ չի ազդում գնի վրա: Դրանում կատեգորիաների միջև էական տարբերություն չկա։
# 2. Թվում է, թե «turbo»-ի(տուռբոշարժիչ) հետ ձգտումն ավելի բարձր գների միջակայք ունի, քան «std»-ը(սովորական շարժիչը):

# %%
def plot_count(x,fig):
    plt.subplot(4,2,fig)
    plt.title(x+' Histogram')
    sns.countplot(cars[x],palette=("magma"))
    plt.subplot(4,2,(fig+1))
    plt.title(x+' vs Price')
    sns.boxplot(x=cars[x], y=cars.price, palette=("magma"))
    
plt.figure(figsize=(15,20))

plot_count('enginelocation', 1)
plot_count('cylindernumber', 3)
plot_count('fuelsystem', 5)
plot_count('drivewheel', 7)

plt.tight_layout()

# %% [markdown]
# #### Եզրակացություն :
#
# 1. «Շարժիչի տեղակայման» կատեգորիաների համար շատ քիչ տվյալներ կան՝ եզրակացություն անելու համար:
# 2. Բալոնների ամենատարածված թիվը «չորս», «վեց» և «հինգ» է: Չնայած «ութ» բալոններն ունեն ամենաբարձր գների միջակայքը:
# 3. «mpfi»-ն և «2bbl»-ը վառելիքի համակարգերի ամենատարածվածն են: «mpfi»-ն և «idi»-ն ունեն ամենաբարձր գների միջակայքը: Սակայն այլ կատեգորիաների համար քիչ տվյալներ կան՝ որևէ իմաստալից եզրակացություն ստանալու համար
# 4. Շատ զգալի տարբերություն կա շարժիչ անիվների կատեգորիայի մեջ: Բարձր շառավիղով մեքենաների մեծ մասը նախընտրում է «rwd» շարժիչ անիվը:

# %% [markdown]
# ### Step 3.2 : Visualising numerical data

# %%
def scatter(x,fig):
    plt.subplot(5,2,fig)
    plt.scatter(cars[x],cars['price'])
    plt.title(x+' vs Price')
    plt.ylabel('Price')
    plt.xlabel(x)

plt.figure(figsize=(10,20))

scatter('carlength', 1)
scatter('carwidth', 2)
scatter('carheight', 3)
scatter('curbweight', 4)

plt.tight_layout()

# %% [markdown]
# #### Եզրակացություն :
#
# 1. «Ավտոմեքենայի լայնությունը», «մեքենայի երկարությունը» և «մոտավոր քաշը» կարծես թե դրական հարաբերակցություն ունեն «գնի» հետ։
# 2. «carheight»-ը գնի հետ կապված որևէ էական միտում չի ցուցաբերում։

# %%
def pp(x,y,z):
    sns.pairplot(cars, x_vars=[x,y,z], y_vars='price',size=4, aspect=1, kind='scatter')
    plt.show()

pp('enginesize', 'boreratio', 'stroke')
pp('compressionratio', 'horsepower', 'peakrpm')
pp('wheelbase', 'citympg', 'highwaympg')
# Out:
# /opt/conda/lib/python3.6/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.6/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.6/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### Եզրակացություն :
#
# 1. «շարժիչի չափը», «boreratio», «ձիաուժ», «անիվի բազա»-  զգալի դրական հարաբերակցություն ունեն գնի հետ:
# 2. «citympg», «highwaympg» - կարծես թե զգալի բացասական հարաբերակցություն ունեն գնի հետ:

# %%
np.corrcoef(cars['carlength'], cars['carwidth'])[0, 1]  
#հաշվարկում է կապի գործակիցը(correlation coefficient) ավտոմեքենաների carlength և carwidth սյունակների միջև
# Out:
# 0.8411182684818455

# %% [markdown]
# ### Step 4 : Deriving new features(Նոր հատկանիշների ստացում)

# %%
#Fuel economy
cars['fueleconomy'] = (0.55 * cars['citympg']) + (0.45 * cars['highwaympg'])

# %% [markdown]
# Highway mpg-ը երեք վարկանիշներից մեկն է, որը Միացյալ Նահանգների Շրջակա միջավայրի պաշտպանության գործակալությունը (EPA) օգտագործում է մեքենայի վառելիքի խնայողությունը որոշելու համար:
#
# City MPG: the score a car will get on average in city conditions, with stopping and starting at lower speeds.

# %%
#Binning the Car Companies based on avg prices of each Company.
cars['price'] = cars['price'].astype('int')
temp = cars.copy()
table = temp.groupby(['CompanyName'])['price'].mean()
temp = temp.merge(table.reset_index(), how='left',on='CompanyName')
bins = [0,10000,20000,40000]
cars_bin=['Budget','Medium','Highend']
cars['carsrange'] = pd.cut(temp['price_y'],bins,right=False,labels=cars_bin)
cars.head()
# Out:
#    car_ID  symboling  CompanyName    ...     price fueleconomy carsrange
# 0       1          3  alfa-romero    ...     13495       23.70    Medium
# 1       2          3  alfa-romero    ...     16500       23.70    Medium
# 2       3          1  alfa-romero    ...     16500       22.15    Medium
# 3       4          2         audi    ...     13950       26.70    Medium
# 4       5          2         audi    ...     17450       19.80    Medium
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Step 5 : Bivariate Analysis
# Երկփոփոխական վերլուծության նպատակն է պարզել, թե արդյոք կա վիճակագրական կապ երկու փոփոխականների միջև, և եթե այո, որքան ուժեղ և որ ուղղությամբ է այդ կապը:

# %%
plt.figure(figsize=(8,6))

plt.title('Fuel economy vs Price')
sns.scatterplot(x=cars['fueleconomy'],y=cars['price'],hue=cars['drivewheel'])
plt.xlabel('Fuel Economy')
plt.ylabel('Price')

plt.show()
plt.tight_layout()           # plt.tight_layout() ֆունկցիան Matplotlib-ում օգտագործվում է ավտոմատ կերպով կարգավորելու լիցքավորումը ենթասյուների  և տվյալների շուրջ

# %% [markdown]
# #### Եզրակացություն :
#
# 1. «Վառելիքի տնտեսումը» ակնհայտ «բացասական հարաբերակցություն» ունի գնի հետ ։

# %%
plt.figure(figsize=(25, 6))       # այս ֆունկցիան օգտագործվում է 25 դյույմ լայնությամբ և 6 դյույմ բարձրությամբ պատկեր ստեղծելու համար:

df = pd.DataFrame(cars.groupby(['fuelsystem','drivewheel','carsrange'])['price'].mean().unstack(fill_value=0))
df.plot.bar()
plt.title('Car Range vs Average Price')
plt.show()

# %% [markdown]
# #### Եզրակացություն :
#
# 1. Բարձր շառավիղով մեքենաները նախընտրում են «rwd» շարժիչ անիվ՝ «idi» կամ «mpfi» վառելիքի համակարգով:

# %% [markdown]
# ### List of significant(կարևոր) variables after Visual analysis :
#
#     - Car Range
#     - Engine Type
#     - Fuel type
#     - Car Body
#     - Aspiration
#     - Cylinder Number
#     - Drivewheel
#     - Curbweight
#     - Car Length
#     - Car width
#     - Engine Size
#     - Boreratio
#     - Horse Power
#     - Wheel base
#     - Fuel Economy

# %% [markdown]
# Հեռացնենք անկարևոր feature-ները,թողնելով միայն կարևորները։

# %%
cars_lr = cars[['price', 'fueltype', 'aspiration','carbody', 'drivewheel','wheelbase',
                  'curbweight', 'enginetype', 'cylindernumber', 'enginesize', 'boreratio','horsepower', 
                    'fueleconomy', 'carlength','carwidth', 'carsrange']]
cars_lr.head()
# Out:
#    price fueltype aspiration    ...     carlength carwidth  carsrange
# 0  13495      gas        std    ...         168.8     64.1     Medium
# 1  16500      gas        std    ...         168.8     64.1     Medium
# 2  16500      gas        std    ...         171.2     65.5     Medium
# 3  13950      gas        std    ...         176.6     66.2     Medium
# 4  17450      gas        std    ...         176.6     66.4     Medium
#
# [5 rows x 16 columns]

# %%
sns.pairplot(cars_lr)      #սրանով  cars_lr տվյալների բազայում փոփոխականների զույգ-զույգ գծապատկեր ենք ստեղծում :
plt.show()

# %% [markdown]
# ### Step 6 : Dummy Variables

# %% [markdown]
# Կեղծ փոփոխականը երկուական փոփոխական է, որն ընդունում է 0 կամ 1 արժեք՝ ցույց տալիս  կատեգորիկ(categorical) էֆեկտի բացակայությունը կամ առկայությունը:

# %%
# Defining the map function
def dummies(x,df):
    temp = pd.get_dummies(df[x], drop_first = True)
    df = pd.concat([df, temp], axis = 1)
    df.drop([x], axis = 1, inplace = True)
    return df
# Applying the function to the cars_lr

cars_lr = dummies('fueltype',cars_lr)
cars_lr = dummies('aspiration',cars_lr)
cars_lr = dummies('carbody',cars_lr)
cars_lr = dummies('drivewheel',cars_lr)
cars_lr = dummies('enginetype',cars_lr)
cars_lr = dummies('cylindernumber',cars_lr)
cars_lr = dummies('carsrange',cars_lr)

# %%
cars_lr.head()
# Out:
#    price  wheelbase  curbweight   ...     two  Medium  Highend
# 0  13495       88.6        2548   ...       0       1        0
# 1  16500       88.6        2548   ...       0       1        0
# 2  16500       94.5        2823   ...       0       1        0
# 3  13950       99.8        2337   ...       0       1        0
# 4  17450       99.4        2824   ...       0       1        0
#
# [5 rows x 31 columns]

# %%
cars_lr.shape
# Out:
# (205, 31)

# %% [markdown]
# ### Step 7 : Train-Test Split and feature scaling(Train-Test Split և հատկությունների մասշտաբավորում)

# %%
from sklearn.model_selection import train_test_split

np.random.seed(0)
df_train, df_test = train_test_split(cars_lr, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
num_vars = ['wheelbase', 'curbweight', 'enginesize', 'boreratio', 'horsepower','fueleconomy','carlength','carwidth','price']
df_train[num_vars] = scaler.fit_transform(df_train[num_vars])
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
df_train.head()
# Out:
#         price  wheelbase  curbweight   ...     two  Medium  Highend
# 122  0.068818   0.244828    0.272692   ...       0       0        0
# 125  0.466890   0.272414    0.500388   ...       0       0        1
# 166  0.122110   0.272414    0.314973   ...       0       0        0
# 1    0.314446   0.068966    0.411171   ...       0       1        0
# 199  0.382131   0.610345    0.647401   ...       0       1        0
#
# [5 rows x 31 columns]

# %%
df_train.describe()      #վիճակագրական ցուցանիշներ
# Out:
#             price   wheelbase     ...          Medium     Highend
# count  143.000000  143.000000     ...      143.000000  143.000000
# mean     0.219309    0.411141     ...        0.412587    0.118881
# std      0.215682    0.205581     ...        0.494030    0.324786
# min      0.000000    0.000000     ...        0.000000    0.000000
# 25%      0.067298    0.272414     ...        0.000000    0.000000
# 50%      0.140343    0.341379     ...        0.000000    0.000000
# 75%      0.313479    0.503448     ...        1.000000    0.000000
# max      1.000000    1.000000     ...        1.000000    1.000000
#
# [8 rows x 31 columns]

# %%
#Correlation using heatmap
plt.figure(figsize = (30, 25))
sns.heatmap(df_train.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# Heatmap-ը  մեզ տալիս է արժեքների գունավոր գնահատում: Կախված ընտրված ներկապնակից, մենք կամ ստանում ենք մուգ գունավոչումներ ավելի բարձր արժեքների համար, կամ հակառակը:
# Կարևոր է նշել, որ կոռելյացիայի գործակիցի արժեքները գտնվում են համապատասխանաբար -1-ից 1 միջակայքի միջև: Որքան բարձր լինի հատկանիշների միջև դրական հարաբերակցությունը, այնքան հարաբերակցության գործակցի արժեքը կտեղափոխվի 1:
# Գների հետ խիստ փոխկապակցված փոփոխականներն են՝ «curbweight», «enginesize», «ձիաուժ», «carwidth» և «highend»:

# %%
#Dividing data into X and y variables
y_train = df_train.pop('price')
X_train = df_train

# %% [markdown]
# ### Step 8 : Model Building

# %% [markdown]
# RFE-ն նշանակում է Recursive Feature Elimination: Դա առանձնահատկությունների ընտրության ալգորիթմ է, որն օգտագործվում է տվյալների բազայից հատկանիշների ենթաբազմություն ընտրելու համար: RFE-ն աշխատում է՝ անընդմեջ հեռացնելով ամենաքիչ կարևոր հատկանիշները տվյալների շտեմարանից և վերապատրաստելով մոդելը: Գործընթացը կրկնվում է այնքան ժամանակ, մինչև հասնեն գործառույթների ցանկալի քանակությունը:

# %%
#RFE
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm       #Statsmodels API-ն հզոր գրադարան է վիճակագրական մոդելավորման և տվյալների վերլուծության համար:
from statsmodels.stats.outliers_influence import variance_inflation_factor
#Variance_inflation_factor() ֆունկցիան statsmodels.stats.outliers_influence գրադարանից օգտագործվում է մի շարք անկախ փոփոխականների համար դիսպերսիայի գնաճի գործակիցը (VIF) հաշվարկելու համար:

# %%
lm = LinearRegression()
lm.fit(X_train,y_train)
rfe = RFE(lm, 10)
rfe = rfe.fit(X_train, y_train)

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('wheelbase', False, 3),
#  ('curbweight', True, 1),
#  ('enginesize', False, 13),
#  ('boreratio', False, 10),
#  ('horsepower', True, 1),
#  ('fueleconomy', True, 1),
#  ('carlength', False, 11),
#  ('carwidth', True, 1),
#  ('gas', False, 17),
#  ('turbo', False, 18),
#  ('hardtop', False, 2),
#  ('hatchback', True, 1),
#  ('sedan', True, 1),
#  ('wagon', True, 1),
#  ('fwd', False, 16),
#  ('rwd', False, 15),
#  ('dohcv', True, 1),
#  ('l', False, 19),
#  ('ohc', False, 7),
#  ('ohcf', False, 8),
#  ('ohcv', False, 9),
#  ('rotor', False, 21),
#  ('five', False, 6),
#  ('four', False, 4),
#  ('six', False, 5),
#  ('three', False, 14),
#  ('twelve', True, 1),
#  ('two', False, 20),
#  ('Medium', False, 12),
#  ('Highend', True, 1)]

# %%
X_train.columns[rfe.support_]    #այս կոդի միջոցով հանում ենք այն հատկանիշների անունները, որոնք ընտրվել են ռեկուրսիվ հատկանիշի վերացման (RFE) ալգորիթմով:
# Out:
# Index(['curbweight', 'horsepower', 'fueleconomy', 'carwidth', 'hatchback',
#        'sedan', 'wagon', 'dohcv', 'twelve', 'Highend'],
#       dtype='object')

# %% [markdown]
# ### Building model using statsmodel, for the detailed statistics(Կառուցման մոդել՝ օգտագործելով statsmodel, մանրամասն վիճակագրության համար)

# %%
X_train_rfe = X_train[X_train.columns[rfe.support_]]
X_train_rfe.head()
# Out:
#      curbweight  horsepower  fueleconomy   ...     dohcv  twelve  Highend
# 122    0.272692    0.083333     0.530864   ...         0       0        0
# 125    0.500388    0.395833     0.213992   ...         0       0        1
# 166    0.314973    0.266667     0.344307   ...         0       0        0
# 1      0.411171    0.262500     0.244170   ...         0       0        0
# 199    0.647401    0.475000     0.122085   ...         0       0        0
#
# [5 rows x 10 columns]

# %%
def build_model(X,y):
    X = sm.add_constant(X) #Adding the constant(Ավելացնելով հաստատուն)
    lm = sm.OLS(y,X).fit() # fitting the model( մոդելի համապատասխանացում)
    print(lm.summary())   # model summary(մոդելի ամփոփում)
    return X
    
def checkVIF(X):
    vif = pd.DataFrame()
    vif['Features'] = X.columns
    vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif['VIF'] = round(vif['VIF'], 2)
    vif = vif.sort_values(by = "VIF", ascending = False)
    return(vif)

# %% [markdown]
# ### MODEL 1

# %%
X_train_new = build_model(X_train_rfe,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.923
# Method:                 Least Squares   F-statistic:                     172.1
# Date:                Fri, 26 Apr 2019   Prob (F-statistic):           1.29e-70
# Time:                        09:01:41   Log-Likelihood:                 205.85
# No. Observations:                 143   AIC:                            -389.7
# Df Residuals:                     132   BIC:                            -357.1
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.0947      0.042     -2.243      0.027      -0.178      -0.011
# ...

# %% [markdown]
# p-value of `twelve` seems to be higher than the significance value of 0.05 (0.079>0.05), hence dropping it as it is insignificant in presence of other variables.

# %%
X_train_new = X_train_rfe.drop(["twelve"], axis = 1)

# %% [markdown]
# ### MODEL 2

# %%
X_train_new = build_model(X_train_new,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.927
# Model:                            OLS   Adj. R-squared:                  0.922
# Method:                 Least Squares   F-statistic:                     187.9
# Date:                Fri, 26 Apr 2019   Prob (F-statistic):           4.25e-71
# Time:                        09:01:41   Log-Likelihood:                 204.17
# No. Observations:                 143   AIC:                            -388.3
# Df Residuals:                     133   BIC:                            -358.7
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.0764      0.041     -1.851      0.066      -0.158       0.005
# ...

# %%
X_train_new = X_train_new.drop(["fueleconomy"], axis = 1)

# %% [markdown]
# ### MODEL 3

# %%
X_train_new = build_model(X_train_new,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.926
# Model:                            OLS   Adj. R-squared:                  0.922
# Method:                 Least Squares   F-statistic:                     209.5
# Date:                Fri, 26 Apr 2019   Prob (F-statistic):           7.85e-72
# Time:                        09:01:42   Log-Likelihood:                 203.07
# No. Observations:                 143   AIC:                            -388.1
# Df Residuals:                     134   BIC:                            -361.5
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0305      0.026     -1.165      0.246      -0.082       0.021
# ...

# %% [markdown]
# The VIF is calculated as follows:
#
# VIF = 1 / (1 - R^2)
# որտեղ R^2-ը մյուս անկախ փոփոխականների վրա անկախ փոփոխականի ռեգրեսիայի որոշման գործակիցն է:
#  VIF-ի 1 արժեքը ցույց է տալիս, որ բազմակողմանիություն(multicollinearity) չկա, մինչդեռ 5-ից ավելի VIF-ը ցույց է տալիս, որ կա զգալի բազմակողմանիություն:

# %%
#Calculating the Variance Inflation Factor(գնաճի գործոնի հաշվարկ)
checkVIF(X_train_new)
# Out:
#      Features    VIF
# 0       const  26.90
# 1  curbweight   8.10
# 5       sedan   6.07
# 4   hatchback   5.63
# 3    carwidth   5.14
# 2  horsepower   3.61
# 6       wagon   3.58
# 8     Highend   1.63
# 7       dohcv   1.46

# %%
X_train_new = X_train_new.drop(["curbweight"], axis = 1)

# %% [markdown]
# ### MODEL 4

# %%
X_train_new = build_model(X_train_new,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.918
# Model:                            OLS   Adj. R-squared:                  0.914
# Method:                 Least Squares   F-statistic:                     215.9
# Date:                Fri, 26 Apr 2019   Prob (F-statistic):           4.70e-70
# Time:                        09:01:42   Log-Likelihood:                 195.77
# No. Observations:                 143   AIC:                            -375.5
# Df Residuals:                     135   BIC:                            -351.8
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0319      0.027     -1.161      0.248      -0.086       0.022
# ...

# %%
checkVIF(X_train_new)
# Out:
#      Features    VIF
# 0       const  26.89
# 4       sedan   6.06
# 3   hatchback   5.54
# 5       wagon   3.47
# 1  horsepower   2.50
# 2    carwidth   2.22
# 7     Highend   1.56
# 6       dohcv   1.21

# %% [markdown]
# dropping `sedan` because of high VIF value.

# %%
X_train_new = X_train_new.drop(["sedan"], axis = 1)

# %% [markdown]
# #### MODEL 5

# %%
X_train_new = build_model(X_train_new,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.909
# Method:                 Least Squares   F-statistic:                     237.6
# Date:                Fri, 26 Apr 2019   Prob (F-statistic):           1.68e-69
# Time:                        09:01:42   Log-Likelihood:                 191.46
# No. Observations:                 143   AIC:                            -368.9
# Df Residuals:                     136   BIC:                            -348.2
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0934      0.018     -5.219      0.000      -0.129      -0.058
# ...

# %%
checkVIF(X_train_new)   #Variance Inflation Factor(գնաճի գործոնի հաշվարկ)
# Out:
#      Features    VIF
# 0       const  10.82
# 1  horsepower   2.39
# 2    carwidth   2.09
# 6     Highend   1.55
# 3   hatchback   1.23
# 5       dohcv   1.21
# 4       wagon   1.11

# %% [markdown]
# Տվյալների բազայից հանենք `wagon`-ը բարձր p-value-ի համար(0.315>0.05).
#
# (P-արժեքը վիճակագրական միջոց է, որն օգտագործվում է պատահականորեն որոշակի արդյունք ստանալու հավանականությունը որոշելու համար: Այլ կերպ ասած, դա չափում է, թե որքանով է հավանական, որ դիտարկված արդյունքները կարող էին տեղի ունենալ, եթե զրոյական վարկածը ճշմարիտ է:)

# %%
X_train_new = X_train_new.drop(["wagon"], axis = 1)

# %% [markdown]
# ### MODEL 6

# %%
X_train_new = build_model(X_train_new,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.912
# Model:                            OLS   Adj. R-squared:                  0.909
# Method:                 Least Squares   F-statistic:                     284.8
# Date:                Fri, 26 Apr 2019   Prob (F-statistic):           1.57e-70
# Time:                        09:01:42   Log-Likelihood:                 190.93
# No. Observations:                 143   AIC:                            -369.9
# Df Residuals:                     137   BIC:                            -352.1
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0970      0.018     -5.530      0.000      -0.132      -0.062
# ...

# %%
checkVIF(X_train_new)
# Out:
#      Features    VIF
# 0       const  10.39
# 1  horsepower   2.39
# 2    carwidth   2.08
# 5     Highend   1.53
# 4       dohcv   1.21
# 3   hatchback   1.13

# %% [markdown]
# ### MODEL 7

# %%
#հանենք dohcv-ն մոդելի վիճակագրության փոփոխությունները տեսնելու համար
X_train_new = X_train_new.drop(["dohcv"], axis = 1)
X_train_new = build_model(X_train_new,y_train)
checkVIF(X_train_new)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     308.0
# Date:                Fri, 26 Apr 2019   Prob (F-statistic):           1.04e-67
# Time:                        09:01:42   Log-Likelihood:                 181.06
# No. Observations:                 143   AIC:                            -352.1
# Df Residuals:                     138   BIC:                            -337.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0824      0.018     -4.480      0.000      -0.119      -0.046
# ...

# %% [markdown]
# ### Step 9 : Residual Analysis of Model(Մոդելի մնացորդային վերլուծություն)

# %%
lm = sm.OLS(y_train,X_train_new).fit()
y_train_price = lm.predict(X_train_new)

# %%
# Plot the histogram of the error terms
fig = plt.figure()
sns.distplot((y_train - y_train_price), bins = 20)          #ստեղծում է վերապատրաստման տվյալների կանխատեսված գների և իրական գների տարբերության նորմալ բաշխման կորը
fig.suptitle('Error Terms', fontsize = 20)                  # Plot heading (վերնագիր) 
plt.xlabel('Errors', fontsize = 18)
# Out:
# Text(0.5, 0, 'Errors')

# %% [markdown]
# Սխալի տերմինները(Error terms) մոտավորապես նորմալ բաշխված են, ուստի գծային մոդելավորման ենթադրությունը  կատարվում է:

# %% [markdown]
# ### Step 10 : Prediction and Evaluation

# %%
#Scaling the test set(Փորձարկման հավաքածուի մասշտաբավորում)
num_vars = ['wheelbase', 'curbweight', 'enginesize', 'boreratio', 'horsepower','fueleconomy','carlength','carwidth','price']
df_test[num_vars] = scaler.fit_transform(df_test[num_vars])
#այս կոդը փոխակերպում է տվյալները df_test DataFrame-ում՝ օգտագործելով scaler օբյեկտը: Scaler օբյեկտը sklearn.preprocessing.StandardScaler օբյեկտ է, որն օգտագործվում է տվյալների նորմալացման համար:
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
#Dividing into X and y
y_test = df_test.pop('price')
X_test = df_test

# %%
# Now let's use our model to make predictions.
X_train_new = X_train_new.drop('const',axis=1)
# X_test_new տվյալների շրջանակի ստեղծում՝ X_test-ից փոփոխականները հանելով
X_test_new = X_test[X_train_new.columns]

# ավելացնենք հաստատուն փոփոխականներ
X_test_new = sm.add_constant(X_test_new)

# %%
# Making predictions
y_pred = lm.predict(X_test_new)

# %% [markdown]
# ### Evaluation of test via comparison of y_pred and y_test

# %%
from sklearn.metrics import r2_score 
r2_score(y_test, y_pred)
# Out:
# 0.8614595209022036

# %% [markdown]
# R-2, որը նաև հայտնի է որպես որոշման գործակից,ցույց է տալիս թե որքանով է մոդելը համապատասխանում տվյալներին:  0-ի և 1-ի միջև ընկած թիվ է, որտեղ 0-ը ցույց է տալիս, որ մոդելն ընդհանրապես չի համապատասխանում տվյալներին, իսկ 1-ը ցույց է տալիս, որ մոդելը լիովին համապատասխանում է :

# %%
#EVALUATION OF THE MODEL
# Plotting y_test and y_pred to understand the spread.
fig = plt.figure()
plt.scatter(y_test,y_pred)
fig.suptitle('y_test vs y_pred', fontsize=20)              # Plot heading 
plt.xlabel('y_test', fontsize=18)                          # X-label
plt.ylabel('y_pred', fontsize=16)
# Out:
# Text(0, 0.5, 'y_pred')

# %% [markdown]
# ### Evaluation of the model using Statistics

# %%
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     308.0
# Date:                Fri, 26 Apr 2019   Prob (F-statistic):           1.04e-67
# Time:                        09:01:43   Log-Likelihood:                 181.06
# No. Observations:                 143   AIC:                            -352.1
# Df Residuals:                     138   BIC:                            -337.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0824      0.018     -4.480      0.000      -0.119      -0.046
# ...

# %% [markdown]
# #### Եզրակացություն :
#
# 1. *R-քառակուսի և ճշգրտված R-քառակուսի (համապատասխանության աստիճան)* - 0.899 և 0.896 - «90%»-ով մոդելը ճշգրիտ է գուշակում(predict):
# 2. *F-stats և Prob(F-stats) (ընդհանուր մոդելի համապատասխանություն)* - 308.0 և 1.04e-67 (մոտ 0.0) - Մոդելը նշանակալի է և բացատրված «90%» ճշտությունը պատահական չէ:
# 3. *p-values* - p-արժեքները բոլոր գործակիցների համար  փոքր են 0,05 նշանակալի մակարդակից,նշանակում է, որ բոլոր կանխատեսիչները վիճակագրորեն նշանակալի են:
# 4. Անկախ փոփոխականների և կախյալ փոփոխականի միջև կապը գծային է: Այս ենթադրությունը հաստատվում է բարձր R-քառակուսի արժեքով, որը ցույց է տալիս, որ մոդելը լավ է համապատասխանում տվյալներին:
# 5. Homoscedasticity. Մնացորդների շեղումը հաստատուն է անկախ փոփոխականների բոլոր արժեքներում: Այս ենթադրությունը հաստատում է Դուրբին-Վաթսոնի վիճակագրությունը, որը մոտ է 2-ին։
# 6. Նորմալություն. մնացորդները նորմալ են  բաշխված։Այս ենթադրությունը հաստատում է Ժարկե-Բերայի վիճակագրությունը(Jarque-Bera թեստի վիճակագրությունը միշտ դրական է, և եթե այն մոտ չէ զրոյին, ապա այն ցույց է տալիս, որ ընտրանքի տվյալները չունեն նորմալ բաշխում:) :
# 7.  Անկախություն. մնացորդները միմյանցից անկախ են: Այս ենթադրությունը հաստատվում է մնացորդների մեջ ավտոկոռելյացիայի բացակայությամբ:
#
# #### Այնուամենայնիվ, մոդելի հետ կապված կան որոշ պոտենցիալ խնդիրներ
#
# Multicollinearity. Անկախ փոփոխականները փոխկապակցված են միմյանց հետ: Սա կարող է խնդիրներ առաջացնել գործակիցների ստանդարտ սխալների հետ՝ դրանք դարձնելով անվստահելի:
# Տվյալներում կարող են լինել արտանետումներ(Outliers): Outliers-ը կարող է ազդել մոդելի համապատասխանության և գործակիցների ստանդարտ սխալների վրա:
# Կարևոր է ուսումնասիրել այս  խնդիրները՝ նախքան մոդելի՝ կանխատեսումներ անելու համար օգտագործելը:

# %% [markdown]
# ![image.png](attachment:image.png)
